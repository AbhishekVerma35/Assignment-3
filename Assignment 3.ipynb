# %%
import numpy as np
import pandas as pd
import random

# %%
df = pd.DataFrame({'ID':np.arange(1, 14988).tolist(), #Created a dataframe of total pharmacist population and gave them all a unique ID
 'practice type':['Community Pharmacy']*11323 + ['Hospital or other health care facility']*2664 + ['Academia or government']*333 + ['Industry']*500 + ['Corporate office, professional practice or clinic']*167}) #Created each practice type and assigned the appropriate proportions 
df
# Out:
#           ID                                      practice type
# 0          1                                 Community Pharmacy
# 1          2                                 Community Pharmacy
# 2          3                                 Community Pharmacy
# 3          4                                 Community Pharmacy
# 4          5                                 Community Pharmacy
# ...      ...                                                ...
# 14982  14983  Corporate office, professional practice or clinic
# 14983  14984  Corporate office, professional practice or clinic
# 14984  14985  Corporate office, professional practice or clinic
# 14985  14986  Corporate office, professional practice or clinic
# 14986  14987  Corporate office, professional practice or clinic
#
# [14987 rows x 2 columns]

# %%
df.groupby('practice type', group_keys = False).apply(lambda x:x.sample(10)) #Randomly selects 10 from each practice type and gives the appropriate ID.
# Out:
#           ID                                      practice type
# 14144  14145                             Academia or government
# 14024  14025                             Academia or government
# 14215  14216                             Academia or government
# 14224  14225                             Academia or government
# 14033  14034                             Academia or government
# 14235  14236                             Academia or government
# 14034  14035                             Academia or government
# 14010  14011                             Academia or government
# 14076  14077                             Academia or government
# 14126  14127                             Academia or government
# 764      765                                 Community Pharmacy
# 1461    1462                                 Community Pharmacy
# 4145    4146                                 Community Pharmacy
# 1107    1108                                 Community Pharmacy
# ...
